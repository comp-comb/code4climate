# %% [markdown]
# # Python Quiz: Lists, Loops, and Indexing
#
# **Name:**
#
# **Date:**
#
#
# ---
# ## 1\. What will be the output of the following Python code?
#
# ```python
# my_list = ['p', 'y', 't', 'h', 'o', 'n']
# print(my_list[2])
# ````
#
# **Answer:**
#
#
#
# ```
# ```
# ---
# ## 2\. What will the following `for` loop print?
#
# ```python
# colors = ['red', 'green', 'blue']
# for color in colors:
#   print('I see ', color)
# ```
#
# **Answer:**
#
#
#
# ```
# ```
# ---
# ## 3\. After this code runs, what will be the output?
#
# ```python
# data = [1, 2, 3]
# data.append(4)
# print(data)
# ```
#
# **Answer:**
#
#
#
# ```
#
# ```
#
# -----
#
# ## 4\. After the following code is executed, what will `new_list` contain?
#
# ```python
# old_list = [1, 2, 3, 4, 5]
# new_list = []
# for num in old_list:
#   if num % 2 == 0:
#     new_list.append(num)
# print(new_list)
# ```
#
# **Answer:**
#
#
#
# ```
# ```
# -----
#
# ## 5\. What will be printed after this loop finishes?
#
# ```python
# count = 0
# for number in [1, 5, 10, 15, 20]:
#     count = count + 1
# print(count)
# ```
#
# **Answer:**
#
#
#
# ```
# ```
# -----
#
# ## 6\. What will this `while` loop print?
#
# ```python
# i = 5
# while i > 0:
#   print(i)
#   i = i - 2
# ```
#
# **Answer:**
#
#
#
# ```
# ```
# -----
#
#
#
# ## 7\. What numbers will be printed by the following `for` loop?
#
# ```python
# for i in range(2, 7):
#   print(i)
# ```
#
# **Answer:**
#
#
#
#
# ```
# ```
# -----
#
# ## 8\. What does this code print?
#
# ```python
# my_list=[1, 5, 10, 15, 20]
# count = 0
# for number in my_list:
#     count = 2* number
# print(count)
# ```
#
# **Answer:**
#
#
#
# ```
# ```
#
# ---
#
# ## 9\. What will be printed after this code executes?
#
# ```python
# my_list = [10, 20, 30, 40]
# temp = my_list[0]
# my_list[0] = my_list[3]
# my_list[3] = temp
# print(my_list)
# ```
#
# **Answer:**
#
#
#
# ```
# ```
# -----
#
# ## 10\. What does the following loop print?
#
# ```python
# i = 0
# while i < 10:
#     print(i)
#     if i == 3:
#         break
#     i = i + 1
# ```
#
# **Answer:**
#
#
#
# ```
# ```
#
# -----

# %%
my_list = ['p', 'y', 't', 'h', 'o', 'n']
print(my_list[2])
# Out:
# t

# %%
colors = ['red', 'green', 'blue']
for color in colors:
  print('I see ', color)
# Out:
# I see  red
# I see  green
# I see  blue

# %%
data = [1, 2, 3]
data.append(4)
print(data)
# Out:
# [1, 2, 3, 4]

# %%
old_list = [1, 2, 3, 4, 5]
new_list = []
for num in old_list:
  if num % 2 == 0:
    new_list.append(num)
print(new_list)
# Out:
# [2, 4]

# %%
count = 0
for number in [1, 5, 10, 15, 20]:
    count = count + 1
print(count)
# Out:
# 5

# %%
i = 5
while i > 0:
  i = i - 2
  print(i)
# Out:
# 3
# 1
# -1

# %%
for i in range(2, 7):
  print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
my_list=[1, 5, 10, 15, 20]
count = 0
for number in my_list:
    count = 2* number
    print(count)
# Out:
# 2
# 10
# 20
# 30
# 40

# %%
my_list = [10, 20, 30, 40]
temp = my_list[0]
my_list[0] = my_list[3]
my_list[3] = temp
print(my_list)
# Out:
# [40, 20, 30, 10]

# %%
i = 0
while i < 10:

    if i == 3:
        print(i)
        break
    i = i + 1
# Out:
# 0
# 1
# 2
# 3
